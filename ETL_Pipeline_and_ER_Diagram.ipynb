# %% [markdown]
# # ETL Pipeline and ER Diagram

# %%
# Load image from local storage
# This library is to create displays
from IPython.display import Image

# %%
# Loading ETL pipeline Example: 
Image(filename="images/About_You_ETL.jpg", width=900, height=200)

# %%
# Loading ERD: 
Image(filename="images/ERD_AboutYou.png", width=900, height=200)
