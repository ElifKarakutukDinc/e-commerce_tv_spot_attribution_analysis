# %% [markdown]
# # ETL Pipeline

# %%
# Load image from local storage
from IPython.display import Image

# %%
# Loading ETL pipeline Example: 
Image(filename="images/About_You_ETL.jpg", width=700, height=200)
